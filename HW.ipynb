# %% [markdown]
# # Variables

# %%
i = 4

# %%
type(i)
# Out:
# int

# %%
f = 3.14

# %%
type(f)
# Out:
# float

# %%
b = True

# %%
type(b)
# Out:
# bool

# %%
hungry = True

# %%
sleep = False

# %%
not hungry
# Out:
# False

# %%
hungry and sleep
# Out:
# False

# %%
hungry or sleep
# Out:
# True

# %%
ss = "This is a string."

# %%
ss
# Out:
# 'This is a string.'

# %% [markdown]
# # List(C array)

# %%
a = [1,2,3,4,5]

# %%
type(a)
# Out:
# list

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(a)
# Out:
# 5

# %%
a[1]
# Out:
# 2

# %%
a[0:2]
# Out:
# [1, 2]

# %%
a[1:]
# Out:
# [2, 3, 4, 5]

# %%
a[-1]
# Out:
# 5

# %%
a[:-2]
# Out:
# [1, 2, 3]

# %%
a[0]=2

# %%
a[0]
# Out:
# 2

# %% [markdown]
# # Tuple

# %%
I = (1,2,3)

# %%
type(I)
# Out:
# tuple

# %%
I[0]
# Out:
# 1

# %%
I[0]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-10527473e91f> in <module>()
# ----> 1 I[0]=2
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Dictionary

# %%
d = {'foo':1,'bar':2.3,'s':'my first dictionary'}

# %%
print(d['s'])
# Out:
# my first dictionary

# %% [markdown]
# # None

# %%
n = None

# %%
type(n)
# Out:
# NoneType

# %% [markdown]
# # Advanced printing

# %%
print("our float value is %s. Our int value is %s."%(f,i))
# Out:
# our float value is 3.14. Our int value is 4.

# %% [markdown]
# # HW

# %%
from skimage import io

img1=io.imread('0.jpg', as_grey=True)

print(type(img1))
print(img1.shape)

io.imshow(img1)
io.show()
# Out:
# <class 'numpy.ndarray'>
# (480, 640)
# C:\Users\vers6914\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
